# %%
import os
from pathlib import Path
import logging

# %%
logging.basicConfig(level=logging.INFO, format='[%(asctime)s]: %(message)s:')

project_name='cnn Classifier'

list_files= [
    ".github/workflows/.gitkeep",
    f"src/{project_name}/__init__.py",
    f"src/{project_name}/components/__init__.py",
    f"src/{project_name}/utils/__init__.py",
    f"src/{project_name}/config/__init__.py",
    f"src/{project_name}/config/configuration.py",
    f"src/{project_name}/pipeline/__init__.py",
    f"src/{project_name}/entity/__init__.py",
    f"src/{project_name}/constants/__init__.py",
    "config/config.yaml",
    "dvc.yaml",
    "params.yaml",
    "requirements.txt",
    "setup.py",
    "research/trials.ipynb",
    "templates/index.html"


]

for file_path in list_files:
    file_path=Path(file_path)
    file_dir,filename=os.path.split(file_path)

    if file_dir !="":

        print(os.makedirs(file_dir,exist_ok=True))
        print(logging.info(f"Creating_directory:{file_dir} for the file {filename}"))

    if (not os.path.exists(file_path)) or (os.path.getsize(file_path)==0):
        with open(file_path,"w") as file:
            print(file)
            logging.info(f"Creating empty file: {file_path}")

    else:
        logging.info(f"{filename} is already exists")
# Out:
# [2024-12-30 09:55:11,628]: Creating_directory:.github\workflows for the file .gitkeep:
# [2024-12-30 09:55:11,631]: Creating empty file: .github\workflows\.gitkeep:
# [2024-12-30 09:55:11,634]: Creating_directory:src\cnn Classifier for the file __init__.py:
# [2024-12-30 09:55:11,637]: Creating empty file: src\cnn Classifier\__init__.py:
# [2024-12-30 09:55:11,640]: Creating_directory:src\cnn Classifier\components for the file __init__.py:
# [2024-12-30 09:55:11,643]: Creating empty file: src\cnn Classifier\components\__init__.py:
# [2024-12-30 09:55:11,646]: Creating_directory:src\cnn Classifier\utils for the file __init__.py:
# [2024-12-30 09:55:11,649]: Creating empty file: src\cnn Classifier\utils\__init__.py:
# [2024-12-30 09:55:11,652]: Creating_directory:src\cnn Classifier\config for the file __init__.py:
# [2024-12-30 09:55:11,654]: Creating empty file: src\cnn Classifier\config\__init__.py:
# [2024-12-30 09:55:11,656]: Creating_directory:src\cnn Classifier\config for the file configuration.py:
# [2024-12-30 09:55:11,659]: Creating empty file: src\cnn Classifier\config\configuration.py:
# [2024-12-30 09:55:11,662]: Creating_directory:src\cnn Classifier\pipeline for the file __init__.py:
# [2024-12-30 09:55:11,669]: Creating empty file: src\cnn Classifier\pipeline\__init__.py:
# [2024-12-30 09:55:11,674]: Creating_directory:src\cnn Classifier\entity for the file __init__.py:
# [2024-12-30 09:55:11,677]: Creating empty file: src\cnn Classifier\entity\__init__.py:
# [2024-12-30 09:55:11,680]: Creating_directory:src\cnn Classifier\constants for the file __init__.py:
# [2024-12-30 09:55:11,682]: Creating empty file: src\cnn Classifier\constants\__init__.py:
# [2024-12-30 09:55:11,686]: Creating_directory:config for the file config.yaml:
# [2024-12-30 09:55:11,693]: Creating empty file: config\config.yaml:
# [2024-12-30 09:55:11,697]: Creating empty file: dvc.yaml:
# [2024-12-30 09:55:11,701]: Creating empty file: params.yaml:
# [2024-12-30 09:55:11,704]: requirements.txt is already exists:
# [2024-12-30 09:55:11,707]: Creating empty file: setup.py:
# [2024-12-30 09:55:11,708]: Creating_directory:research for the file trials.ipynb:
# [2024-12-30 09:55:11,710]: Creating empty file: research\trials.ipynb:
# [2024-12-30 09:55:11,711]: Creating_directory:templates for the file index.html:
# [2024-12-30 09:55:11,713]: Creating empty file: templates\index.html:
# None
# None
# <_io.TextIOWrapper name='.github\\workflows\\.gitkeep' mode='w' encoding='UTF-8'>
# None
# None
# <_io.TextIOWrapper name='src\\cnn Classifier\\__init__.py' mode='w' encoding='UTF-8'>
# None
# None
# <_io.TextIOWrapper name='src\\cnn Classifier\\components\\__init__.py' mode='w' encoding='UTF-8'>
# None
# None
# <_io.TextIOWrapper name='src\\cnn Classifier\\utils\\__init__.py' mode='w' encoding='UTF-8'>
# None
# None
# <_io.TextIOWrapper name='src\\cnn Classifier\\config\\__init__.py' mode='w' encoding='UTF-8'>
# None
# None
# <_io.TextIOWrapper name='src\\cnn Classifier\\config\\configuration.py' mode='w' encoding='UTF-8'>
# None
# None
# <_io.TextIOWrapper name='src\\cnn Classifier\\pipeline\\__init__.py' mode='w' encoding='UTF-8'>
# None
# None
# <_io.TextIOWrapper name='src\\cnn Classifier\\entity\\__init__.py' mode='w' encoding='UTF-8'>
# None
# None
# <_io.TextIOWrapper name='src\\cnn Classifier\\constants\\__init__.py' mode='w' encoding='UTF-8'>
# None
# None
# <_io.TextIOWrapper name='config\\config.yaml' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='dvc.yaml' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='params.yaml' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='setup.py' mode='w' encoding='UTF-8'>
# None
# None
# <_io.TextIOWrapper name='research\\trials.ipynb' mode='w' encoding='UTF-8'>
# None
# None
# <_io.TextIOWrapper name='templates\\index.html' mode='w' encoding='UTF-8'>
